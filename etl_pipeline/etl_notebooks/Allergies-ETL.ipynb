# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re

# %%
data = pd.read_csv(os.path.join(os.getcwd(), "..", "..", "Datasets", "csv", "allergies.csv"))

# %%
data
# Out:
#      2024-09-07  Unnamed: 1  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4  \
# 0    2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 1    2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 2    2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 3    2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 4    2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# ..          ...         ...                                   ...
# 745  1980-07-06         NaN  32448f23-2620-9f37-889f-c561c989874f
# 746  1980-07-06         NaN  32448f23-2620-9f37-889f-c561c989874f
# 747  1980-07-06         NaN  32448f23-2620-9f37-889f-c561c989874f
# 748  1980-07-06         NaN  32448f23-2620-9f37-889f-c561c989874f
# 749  1980-07-06         NaN  32448f23-2620-9f37-889f-c561c989874f
#
#      ce99e30f-8737-c76d-5d15-5faacf9db545  609328004  SNOMED-CT  \
# 0    ce99e30f-8737-c76d-5d15-5faacf9db545  288328004  SNOMED-CT
# ...

# %%
for index, col in enumerate(data.columns):
    print(f"Index: {index}, col name: {col} \n")
# Out:
# Index: 0, col name: 2024-09-07
#
# Index: 1, col name: Unnamed: 1
#
# Index: 2, col name: ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
#
# Index: 3, col name: ce99e30f-8737-c76d-5d15-5faacf9db545
#
# Index: 4, col name: 609328004
#
# Index: 5, col name: SNOMED-CT
#
# Index: 6, col name: Allergic disposition (finding)
#
# Index: 7, col name: allergy
#
# Index: 8, col name: environment
#
# Index: 9, col name: Unnamed: 9
#
# Index: 10, col name: Unnamed: 10
#
# Index: 11, col name: Unnamed: 11
#
# Index: 12, col name: Unnamed: 12
#
# Index: 13, col name: Unnamed: 13
#
# Index: 14, col name: Unnamed: 14

# %%
#Find out rows having least number of NaN values for better searching in json
data[data.isna().sum(axis=1) == 1]
# Out:
#      2024-09-07  Unnamed: 1  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4  \
# 6    2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 13   2001-09-15         NaN  993e82c0-3f6c-a21e-1337-a120f8040c35
# 15   2001-09-15         NaN  993e82c0-3f6c-a21e-1337-a120f8040c35
# 19   1994-10-07         NaN  0bbd30a9-5e1d-3a36-1033-f4159628d71f
# 22   1994-10-07         NaN  0bbd30a9-5e1d-3a36-1033-f4159628d71f
# ..          ...         ...                                   ...
# 731  2002-10-30         NaN  b9aa85ca-3482-4454-69ce-051e47814156
# 737  2007-06-12         NaN  cab8a77b-53f1-82db-a483-c869280e4626
# 739  2010-03-28         NaN  12a2e502-b3e7-3e16-f1ae-88b813bb4bf3
# 746  1980-07-06         NaN  32448f23-2620-9f37-889f-c561c989874f
# 749  1980-07-06         NaN  32448f23-2620-9f37-889f-c561c989874f
#
#      ce99e30f-8737-c76d-5d15-5faacf9db545  609328004  SNOMED-CT  \
# 6    ce99e30f-8737-c76d-5d15-5faacf9db545  762952008  SNOMED-CT
# ...

# %%
new_cols = ['recorded_date', '_', 'uuid', 'encounter_id', 'causative_agent_id', 'code_system', 'causative_agent', 'agent_aim', 'agent_class', 'primary_reaction_id', 'primary_reaction', 'primary_reaction_severity', 'symptom_id', 'symptom_observed', 'symptom_severity']
old_cols = data.columns

for new, old in zip(new_cols, old_cols):
    data.rename(columns={old: new}, inplace=True)

data.drop(inplace=True, columns=[col for col in data.columns if col == "_"])
data
# Out:
#     recorded_date                                  uuid  \
# 0      2024-09-07  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 1      2024-09-07  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 2      2024-09-07  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 3      2024-09-07  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 4      2024-09-07  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# ..            ...                                   ...
# 745    1980-07-06  32448f23-2620-9f37-889f-c561c989874f
# 746    1980-07-06  32448f23-2620-9f37-889f-c561c989874f
# 747    1980-07-06  32448f23-2620-9f37-889f-c561c989874f
# 748    1980-07-06  32448f23-2620-9f37-889f-c561c989874f
# 749    1980-07-06  32448f23-2620-9f37-889f-c561c989874f
#
#                              encounter_id  causative_agent_id code_system  \
# 0    ce99e30f-8737-c76d-5d15-5faacf9db545           288328004   SNOMED-CT
# 1    ce99e30f-8737-c76d-5d15-5faacf9db545            84489001   SNOMED-CT
# ...

# %%
data.iloc[:, 6].value_counts()
# Out:
# Allergic disposition (finding)
# Allergic disposition (finding)     131
# Mold (organism)                     79
# Animal dander (substance)           72
# House dust mite (organism)          60
# Grass pollen (substance)            59
# Tree pollen (substance)             54
# Shellfish (substance)               35
# Aspirin                             34
# Wheat (substance)                   34
# Bee venom (substance)               29
# Latex (substance)                   24
# Peanut (substance)                  23
# Tree nut (substance)                22
# Fish (substance)                    22
# Eggs (edible) (substance)           19
# Lisinopril                          16
# Penicillin V                        15
# Cow's milk (substance)              10
# Glycine max (substance)              5
# Sulfamethoxazole / Trimethoprim      4
# Ibuprofen                            2
# cefdinir                             1
# Name: count, dtype: int64

# %%
data[data.iloc[:, 5] == "RxNorm"]
# Out:
#      2024-09-07  Unnamed: 1  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4  \
# 5    2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 35   2009-09-26         NaN  6de47fa5-b9d4-fac7-a8d3-40ee8284581a
# 51   2000-05-18         NaN  0290b772-cf4b-8f87-a4a0-33a291544c2c
# 65   2001-09-14         NaN  ee64dd79-a03f-d761-b1fc-1da060ecc2c8
# 75   2002-04-11         NaN  cba4359c-9f27-ce4e-fe67-fc995226a209
# ..          ...         ...                                   ...
# 702  1963-09-05         NaN  5acf9e38-0173-2600-29b3-0d2928cf13a7
# 705  1953-12-02         NaN  932bda91-670b-655d-43e2-f8c772ea6c49
# 708  1983-04-16         NaN  a92f9975-2e23-95e7-6626-8e5fe7d5a5a8
# 730  2002-10-30         NaN  b9aa85ca-3482-4454-69ce-051e47814156
# 737  2007-06-12         NaN  cab8a77b-53f1-82db-a483-c869280e4626
#
#      ce99e30f-8737-c76d-5d15-5faacf9db545  609328004 SNOMED-CT  \
# 5    ce99e30f-8737-c76d-5d15-5faacf9db545       1191    RxNorm
# ...

# %%
data[data.iloc[:, 2] == "ce99e30f-8737-c76d-2be7-9e3a65f3ffa4"]
# Out:
#    2024-09-07  Unnamed: 1  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4  \
# 0  2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 1  2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 2  2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 3  2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 4  2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 5  2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
# 6  2024-09-07         NaN  ce99e30f-8737-c76d-2be7-9e3a65f3ffa4
#
#    ce99e30f-8737-c76d-5d15-5faacf9db545  609328004  SNOMED-CT  \
# 0  ce99e30f-8737-c76d-5d15-5faacf9db545  288328004  SNOMED-CT
# 1  ce99e30f-8737-c76d-5d15-5faacf9db545   84489001  SNOMED-CT
# 2  ce99e30f-8737-c76d-5d15-5faacf9db545  260147004  SNOMED-CT
# 3  ce99e30f-8737-c76d-5d15-5faacf9db545  264287008  SNOMED-CT
# 4  ce99e30f-8737-c76d-5d15-5faacf9db545  256277009  SNOMED-CT
# 5  ce99e30f-8737-c76d-5d15-5faacf9db545       1191     RxNorm
# ...
